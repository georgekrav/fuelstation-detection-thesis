# %% [markdown]
# # Google Geocoding - Συγκριτική Ανάλυση
# ## Σύγκριση μεθόδων geocoding
#
# Δοκιμή 3 μεθόδων:
# - **Run 1**: μόνο διεύθυνση
# - **Run 2**: διεύθυνση + νομός
# - **Run 3**: διεύθυνση + δήμος + νομός
# - **Best**: καλύτερη από τις 3 (με μικρότερη απόσταση)

# %% [markdown]
# ### 1. Διαμόρφωση

# %%
import pandas as pd
import googlemaps
import numpy as np
from   math import radians, cos, sin, asin, sqrt
import os
from   dotenv import load_dotenv
import time
import matplotlib.pyplot as plt
import seaborn as sns
import json

load_dotenv()
GOOGLE_API_KEY = os.getenv('GOOGLE_MAPS_API_KEY')

if not GOOGLE_API_KEY:
    print("LATHOS: Den vrethike to API Key!")
else:
    print("To API Key fortothike!")

gmaps = googlemaps.Client(key=GOOGLE_API_KEY)

INPUT_FILE = "/Users/geo/Desktop/fuelstation-detection-thesis/data/ALL_cleaned.xlsx"
OUTPUT_FILE = "/Users/geo/Desktop/fuelstation-detection-thesis/data/geocoding_comparison.xlsx"
CACHE_FILE = "/Users/geo/Desktop/fuelstation-detection-thesis/data/geocoding_cache.json"

# Accuracy scoring - vathmologia akribeias
ACCURACY_SCORES = {
    'ROOFTOP': 5,
    'RANGE_INTERPOLATED': 3,
    'GEOMETRIC_CENTER': 2,
    'APPROXIMATE': 1,
    None: 0,
    'FAILED': 0
}
# Out:
# To API Key fortothike!

# %% [markdown]
# ### 2. Φόρτωση Δεδομένων

# %%
df = pd.read_excel(INPUT_FILE, sheet_name='Cleaned')
print(f"Fortothikan {len(df)} stathmoi")
df.head()
# Out:
# Fortothikan 1026 stathmoi
#    gasStationID                    gasStationAddress  gasStationLat  \
# 0         11078        6o χιλ. ΕΟ Αγρινιου Ιωαννινων      38.670417
# 1            28     2,5 ΧΛΜ Ε.Ο. ΙΩΑΝΝΙΝΩΝ ΑΝΤΙΡΡΙΟΥ      38.337761
# 2            31            4ο ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ ΘΕΡΜΟΥ      38.608541
# 3            36  5ο ΧΛΜ. ΝΑΥΠΑΚΤΟΥ-ΘΕΡΜΟΥ, ΝΑΥΠΑΚΤΟΣ      38.403461
# 4         10861      6 χλμ Ε.Ο. ΑΓΡΙΝΙΟΥ - ΙΩΑΝΝΙΝΩΝ      38.670355
#
#    gasStationLong locationType             ddName municipalityName  \
# 0       21.346708      ROOFTOP       Δ.Δ.Νεάπολης   ΔΗΜΟΣ ΝΕΑΠΟΛΗΣ
# 1       21.745611      ROOFTOP      Δ.Δ.Αντιρρίου  ΔΗΜΟΣ ΑΝΤΙΡΡΙΟΥ
# 2       21.449021      ROOFTOP  Δ.Δ.Νέας Αβόρανης   ΔΗΜΟΣ ΘΕΣΤΙΕΩΝ
# 3       21.785474      ROOFTOP     Δ.Δ.Αφροξυλιάς  ΔΗΜΟΣ ΝΑΥΠΑΚΤΟΥ
# 4       21.360866      ROOFTOP       Δ.Δ.Αγρινίου   ΔΗΜΟΣ ΑΓΡΙΝΙΟΥ
#
#          countyName  cluster
# 0  ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ        0
# 1  ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ        1
# 2  ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ        2
# 3  ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ        3
# 4  ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ        4

# %% [markdown]
# ### 3. Βοηθητικές Συναρτήσεις

# %%
def haversine_distance(lat1, lon1, lat2, lon2):
    # Ypologizei apostasi se metra.
    if pd.isna(lat1) or pd.isna(lon1) or pd.isna(lat2) or pd.isna(lon2):
        return None
    
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    
    return c * 6371000


# Cache functions - synartiseis cache
def load_cache():
    """Load cache from JSON file - fortosi cache apo JSON arxeio"""
    try:
        if os.path.exists(CACHE_FILE):
            with open(CACHE_FILE, 'r', encoding='utf-8') as f:
                cache = json.load(f)
            print(f"Cache fortothike: {len(cache)} cached addresses")
            return cache
        else:
            print("Den vrethike cache arxeio - tha dimiourgithei neo")
            return {}
    except Exception as e:
        print(f"Sfalma kata ti fortosi cache: {e}")
        return {}

def save_cache(cache):
    """Save cache to JSON file - apothikefsi cache se JSON arxeio"""
    try:
        # Create directory if it doesn't exist - dimiourgei ton fakelo an den yparchi
        os.makedirs(os.path.dirname(CACHE_FILE), exist_ok=True)
        
        with open(CACHE_FILE, 'w', encoding='utf-8') as f:
            json.dump(cache, f, ensure_ascii=False, indent=2)
        print(f"Cache apothikeythike: {len(cache)} addresses sto {CACHE_FILE}")
    except Exception as e:
        print(f"Sfalma kata tin apothikefsi cache: {e}")

# Load existing cache - fortosi yparxontos cache
geocoding_cache = load_cache()

def geocode_address(address):
    # Geocode mia dieuthinsi me persistent caching.
    
    # Check cache first - elegxos cache proto
    if address in geocoding_cache:
        print(f"    [CACHE HIT] Using cached result for: {address[:50]}...")
        return geocoding_cache[address]
    
    try:
        result = gmaps.geocode(address, region='gr')
        
        if not result:
            geocoding_cache[address] = None  # Cache negative results too
            return None
        
        location = result[0]['geometry']['location']
        accuracy = result[0]['geometry']['location_type']
        
        geocoded_result = {
            'lat': location['lat'],
            'lng': location['lng'],
            'accuracy': accuracy
        }
        
        # Store in cache - apothikefsi sto cache
        geocoding_cache[address] = geocoded_result
        print(f"    [API CALL] New geocoding for: {address[:50]}...")
        
        return geocoded_result
        
    except Exception as e:
        print(f"Sfalma: {e}")
        geocoding_cache[address] = None  # Cache error results too
        return None


def compare_methods(row):
    # Dokimazi 3 methods kai krataei to best.
    address = row['gasStationAddress']
    county = row.get('countyName', '')
    municipality = row.get('municipalityName', '')
    
    ground_truth_lat = row['gasStationLat']
    ground_truth_lng = row['gasStationLong']
    
    results = {}
    
    # Run 1: Address only
    print(f"  Run 1: mono diefthinsi")
    result1 = geocode_address(address)
    if result1:
        distance1 = haversine_distance(
            ground_truth_lat, ground_truth_lng,
            result1['lat'], result1['lng']
        )
        score1 = ACCURACY_SCORES.get(result1['accuracy'], 0)
        results['run1'] = {
            **result1,
            'distance': distance1,
            'score': score1
        }
        print(f"    → {result1['accuracy']} (vathmologia:{score1}), apostasi: {distance1:.1f}m")
    else:
        results['run1'] = None
        print(f"    → APOTYCHIA")
    
    time.sleep(0.1)
    
    # Run 2: Address + County
    query2 = f"{address}, {county}"
    print(f"  Run 2: diefthinsi + nomos")
    result2 = geocode_address(query2)
    if result2:
        distance2 = haversine_distance(
            ground_truth_lat, ground_truth_lng,
            result2['lat'], result2['lng']
        )
        score2 = ACCURACY_SCORES.get(result2['accuracy'], 0)
        results['run2'] = {
            **result2,
            'distance': distance2,
            'score': score2
        }
        print(f"    → {result2['accuracy']} (vathmologia:{score2}), apostasi: {distance2:.1f}m")
    else:
        results['run2'] = None
        print(f"    → APOTYCHIA")
    
    time.sleep(0.1)
    
    # Run 3: Address + Municipality + County
    query3 = f"{address}, {municipality}, {county}"
    print(f"  Run 3: diefthinsi + dimos + nomos")
    result3 = geocode_address(query3)
    if result3:
        distance3 = haversine_distance(
            ground_truth_lat, ground_truth_lng,
            result3['lat'], result3['lng']
        )
        score3 = ACCURACY_SCORES.get(result3['accuracy'], 0)
        results['run3'] = {
            **result3,
            'distance': distance3,
            'score': score3
        }
        print(f"    → {result3['accuracy']} (vathmologia:{score3}), apostasi: {distance3:.1f}m")
    else:
        results['run3'] = None
        print(f"    → APOTYCHIA")
    
    # Best method (mikroteri distance)
    valid_methods = {k: v for k, v in results.items() if v is not None}
    
    if valid_methods:
        # Krataei to method me mikroteri distance
        best_method = min(valid_methods.keys(), key=lambda k: valid_methods[k]['distance'])
        results['best'] = {
            **valid_methods[best_method],
            'best_method': best_method
        }
        print(f"  → KALYTERI: {best_method} ({results['best']['accuracy']}, {results['best']['distance']:.1f}m)")
    else:
        results['best'] = None
    
    return results


# Function to show cache statistics - synartisi gia statistika cache
def show_cache_stats():
    print(f"\nCache Statistics:")
    print(f"- Cached addresses: {len(geocoding_cache)}")
    successful_cache = sum(1 for v in geocoding_cache.values() if v is not None)
    print(f"- Successful geocodings: {successful_cache}")
    print(f"- Failed geocodings: {len(geocoding_cache) - successful_cache}")
    print(f"- Cache file: {CACHE_FILE}")
    
    if len(geocoding_cache) > 0:
        cache_hit_potential = len(geocoding_cache) - len(set(geocoding_cache.keys()))
        print(f"- Potential API calls saved: {cache_hit_potential}")


# Function to save cache at the end - synartisi apothikefsis cache sto telos
def save_cache_and_stats():
    save_cache(geocoding_cache)
    show_cache_stats()
# Out:
# Cache fortothike: 3064 cached addresses

# %% [markdown]
# ### 4. Επιλογή Δεδομένων (Όλες οι Εγγραφές)

# %%
# Use all records - xrisimopoiei oles tis egrafes
df_sample = df.copy()

print(f"Tha ginei geocoding gia {len(df_sample)} stathmous (OLES OI EGRAFES)")
print(f"Ypologizomenos xronos: ~{len(df_sample) * 3 * 0.5:.0f} lepta")
print("\nProtos deigmata:")
display(df_sample[['gasStationID', 'gasStationAddress', 'countyName']].head())
# Out:
# Tha ginei geocoding gia 1026 stathmous (OLES OI EGRAFES)
# Ypologizomenos xronos: ~1539 lepta
#
# Protos deigmata:
#    gasStationID                    gasStationAddress        countyName
# 0         11078        6o χιλ. ΕΟ Αγρινιου Ιωαννινων  ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ
# 1            28     2,5 ΧΛΜ Ε.Ο. ΙΩΑΝΝΙΝΩΝ ΑΝΤΙΡΡΙΟΥ  ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ
# 2            31            4ο ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ ΘΕΡΜΟΥ  ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ
# 3            36  5ο ΧΛΜ. ΝΑΥΠΑΚΤΟΥ-ΘΕΡΜΟΥ, ΝΑΥΠΑΚΤΟΣ  ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ
# 4         10861      6 χλμ Ε.Ο. ΑΓΡΙΝΙΟΥ - ΙΩΑΝΝΙΝΩΝ  ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ

# %% [markdown]
# ### 5. Εκτέλεση Σύγκρισης

# %%
print("\n")
print("SIGKRISI METHODON GEOCODING")
print("\n")

test_results = []

for idx, row in df_sample.iterrows():
    print(f"\nID Stathmou: {row['gasStationID']}")
    print(f"Pragmatikes syntetetagmenes: ({row['gasStationLat']:.6f}, {row['gasStationLong']:.6f})")
    
    results = compare_methods(row)
    
    test_results.append({
        'gasStationID': row['gasStationID'],
        'ground_truth_lat': row['gasStationLat'],
        'ground_truth_lng': row['gasStationLong'],
        **results
    })

print("\n")
print("I DOKIMI OLOKLIROTHIKE")
print("\n")

# Save cache and show statistics - apothikefsi cache kai emfanisi statistikon
save_cache_and_stats()
# Out:
# SIGKRISI METHODON GEOCODING
#
#
#
# ID Stathmou: 11078
# Pragmatikes syntetetagmenes: (38.670417, 21.346708)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 6o χιλ. ΕΟ Αγρινιου Ιωαννινων...
#     → APPROXIMATE (vathmologia:1), apostasi: 118384.8m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 6o χιλ. ΕΟ Αγρινιου Ιωαννινων, ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 5896.9m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 6o χιλ. ΕΟ Αγρινιου Ιωαννινων, ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 5896.9m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 6o χιλ. ΕΟ Αγρινιου Ιωαννινων, ΔΗΜΟΣ ΝΕΑΠΟΛΗΣ, ΑΙΤ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2170.3m
#   → KALYTERI: run3 (APPROXIMATE, 2170.3m)
#
# ID Stathmou: 28
# Pragmatikes syntetetagmenes: (38.337761, 21.745611)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 2,5 ΧΛΜ Ε.Ο. ΙΩΑΝΝΙΝΩΝ ΑΝΤΙΡΡΙΟΥ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1820.5m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 6o χιλ. ΕΟ Αγρινιου Ιωαννινων, ΔΗΜΟΣ ΝΕΑΠΟΛΗΣ, ΑΙΤ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2170.3m
#   → KALYTERI: run3 (APPROXIMATE, 2170.3m)
#
# ID Stathmou: 28
# Pragmatikes syntetetagmenes: (38.337761, 21.745611)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 2,5 ΧΛΜ Ε.Ο. ΙΩΑΝΝΙΝΩΝ ΑΝΤΙΡΡΙΟΥ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1820.5m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 2,5 ΧΛΜ Ε.Ο. ΙΩΑΝΝΙΝΩΝ ΑΝΤΙΡΡΙΟΥ, ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1820.5m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 2,5 ΧΛΜ Ε.Ο. ΙΩΑΝΝΙΝΩΝ ΑΝΤΙΡΡΙΟΥ, ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1820.5m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 2,5 ΧΛΜ Ε.Ο. ΙΩΑΝΝΙΝΩΝ ΑΝΤΙΡΡΙΟΥ, ΔΗΜΟΣ ΑΝΤΙΡΡΙΟΥ,...
#     → APPROXIMATE (vathmologia:1), apostasi: 1820.5m
#   → KALYTERI: run1 (APPROXIMATE, 1820.5m)
#
# ID Stathmou: 31
# Pragmatikes syntetetagmenes: (38.608541, 21.449021)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 4ο ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ ΘΕΡΜΟΥ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2195.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 2,5 ΧΛΜ Ε.Ο. ΙΩΑΝΝΙΝΩΝ ΑΝΤΙΡΡΙΟΥ, ΔΗΜΟΣ ΑΝΤΙΡΡΙΟΥ,...
#     → APPROXIMATE (vathmologia:1), apostasi: 1820.5m
#   → KALYTERI: run1 (APPROXIMATE, 1820.5m)
#
# ID Stathmou: 31
# Pragmatikes syntetetagmenes: (38.608541, 21.449021)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 4ο ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ ΘΕΡΜΟΥ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2195.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 4ο ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ ΘΕΡΜΟΥ, ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 8934.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 4ο ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ ΘΕΡΜΟΥ, ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 8934.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 4ο ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ ΘΕΡΜΟΥ, ΔΗΜΟΣ ΘΕΣΤΙΕΩΝ, ΑΙΤΩΛΟΑ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1010.9m
#   → KALYTERI: run3 (GEOMETRIC_CENTER, 1010.9m)
#
# ID Stathmou: 36
# Pragmatikes syntetetagmenes: (38.403461, 21.785474)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ. ΝΑΥΠΑΚΤΟΥ-ΘΕΡΜΟΥ, ΝΑΥΠΑΚΤΟΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3224.9m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 4ο ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ ΘΕΡΜΟΥ, ΔΗΜΟΣ ΘΕΣΤΙΕΩΝ, ΑΙΤΩΛΟΑ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1010.9m
#   → KALYTERI: run3 (GEOMETRIC_CENTER, 1010.9m)
#
# ID Stathmou: 36
# Pragmatikes syntetetagmenes: (38.403461, 21.785474)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ. ΝΑΥΠΑΚΤΟΥ-ΘΕΡΜΟΥ, ΝΑΥΠΑΚΤΟΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3224.9m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ. ΝΑΥΠΑΚΤΟΥ-ΘΕΡΜΟΥ, ΝΑΥΠΑΚΤΟΣ, ΑΙΤΩΛΟΑΚΑΡΝΑΝ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3224.9m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ. ΝΑΥΠΑΚΤΟΥ-ΘΕΡΜΟΥ, ΝΑΥΠΑΚΤΟΣ, ΑΙΤΩΛΟΑΚΑΡΝΑΝ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3224.9m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ. ΝΑΥΠΑΚΤΟΥ-ΘΕΡΜΟΥ, ΝΑΥΠΑΚΤΟΣ, ΔΗΜΟΣ ΝΑΥΠΑΚΤ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3224.9m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 3224.9m)
#
# ID Stathmou: 10861
# Pragmatikes syntetetagmenes: (38.670355, 21.360866)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 6 χλμ Ε.Ο. ΑΓΡΙΝΙΟΥ - ΙΩΑΝΝΙΝΩΝ...
#     → APPROXIMATE (vathmologia:1), apostasi: 6627.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ. ΝΑΥΠΑΚΤΟΥ-ΘΕΡΜΟΥ, ΝΑΥΠΑΚΤΟΣ, ΔΗΜΟΣ ΝΑΥΠΑΚΤ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3224.9m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 3224.9m)
#
# ID Stathmou: 10861
# Pragmatikes syntetetagmenes: (38.670355, 21.360866)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 6 χλμ Ε.Ο. ΑΓΡΙΝΙΟΥ - ΙΩΑΝΝΙΝΩΝ...
#     → APPROXIMATE (vathmologia:1), apostasi: 6627.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 6 χλμ Ε.Ο. ΑΓΡΙΝΙΟΥ - ΙΩΑΝΝΙΝΩΝ, ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 4966.0m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 6 χλμ Ε.Ο. ΑΓΡΙΝΙΟΥ - ΙΩΑΝΝΙΝΩΝ, ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 4966.0m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 6 χλμ Ε.Ο. ΑΓΡΙΝΙΟΥ - ΙΩΑΝΝΙΝΩΝ, ΔΗΜΟΣ ΑΓΡΙΝΙΟΥ, Α...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 4966.0m
#   → KALYTERI: run2 (GEOMETRIC_CENTER, 4966.0m)
#
# ID Stathmou: 41
# Pragmatikes syntetetagmenes: (38.668546, 21.300644)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 12 ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ - ΑΜΦΙΛΟΧΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 9765.2m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 6 χλμ Ε.Ο. ΑΓΡΙΝΙΟΥ - ΙΩΑΝΝΙΝΩΝ, ΔΗΜΟΣ ΑΓΡΙΝΙΟΥ, Α...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 4966.0m
#   → KALYTERI: run2 (GEOMETRIC_CENTER, 4966.0m)
#
# ID Stathmou: 41
# Pragmatikes syntetetagmenes: (38.668546, 21.300644)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 12 ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ - ΑΜΦΙΛΟΧΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 9765.2m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 12 ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ - ΑΜΦΙΛΟΧΙΑΣ, ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 9765.2m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 12 ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ - ΑΜΦΙΛΟΧΙΑΣ, ΑΙΤΩΛΟΑΚΑΡΝΑΝΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 9765.2m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 12 ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ - ΑΜΦΙΛΟΧΙΑΣ, ΔΗΜΟΣ ΣΤΡΑΤΟΥ, ΑΙ...
#     → APPROXIMATE (vathmologia:1), apostasi: 24572.0m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 9765.2m)
#
# ID Stathmou: 47
# Pragmatikes syntetetagmenes: (38.409519, 22.959381)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 6 χιλ. Ε.Ο.  ΛΙΒΑΔΕΙΑΣ-ΘΗΒΑΣ...
#     → APOTYCHIA
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 12 ΧΛΜ ΕΟ ΑΓΡΙΝΙΟΥ - ΑΜΦΙΛΟΧΙΑΣ, ΔΗΜΟΣ ΣΤΡΑΤΟΥ, ΑΙ...
#     → APPROXIMATE (vathmologia:1), apostasi: 24572.0m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 9765.2m)
#
# ID Stathmou: 47
# Pragmatikes syntetetagmenes: (38.409519, 22.959381)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 6 χιλ. Ε.Ο.  ΛΙΒΑΔΕΙΑΣ-ΘΗΒΑΣ...
#     → APOTYCHIA
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 6 χιλ. Ε.Ο.  ΛΙΒΑΔΕΙΑΣ-ΘΗΒΑΣ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 8003.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 6 χιλ. Ε.Ο.  ΛΙΒΑΔΕΙΑΣ-ΘΗΒΑΣ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 8003.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 6 χιλ. Ε.Ο.  ΛΙΒΑΔΕΙΑΣ-ΘΗΒΑΣ, ΔΗΜΟΣ ΛΕΒΑΔΕΩΝ, ΒΟΙΩ...
#     → APPROXIMATE (vathmologia:1), apostasi: 8003.6m
#   → KALYTERI: run2 (APPROXIMATE, 8003.6m)
#
# ID Stathmou: 48
# Pragmatikes syntetetagmenes: (38.441174, 22.833053)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 4 χλμ Λιβαδειάς-Δελφών...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2847.9m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 6 χιλ. Ε.Ο.  ΛΙΒΑΔΕΙΑΣ-ΘΗΒΑΣ, ΔΗΜΟΣ ΛΕΒΑΔΕΩΝ, ΒΟΙΩ...
#     → APPROXIMATE (vathmologia:1), apostasi: 8003.6m
#   → KALYTERI: run2 (APPROXIMATE, 8003.6m)
#
# ID Stathmou: 48
# Pragmatikes syntetetagmenes: (38.441174, 22.833053)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 4 χλμ Λιβαδειάς-Δελφών...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2847.9m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 4 χλμ Λιβαδειάς-Δελφών, ΒΟΙΩΤΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2847.9m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 4 χλμ Λιβαδειάς-Δελφών, ΒΟΙΩΤΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2847.9m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 4 χλμ Λιβαδειάς-Δελφών, ΔΗΜΟΣ ΛΕΒΑΔΕΩΝ, ΒΟΙΩΤΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2847.9m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 2847.9m)
#
# ID Stathmou: 49
# Pragmatikes syntetetagmenes: (38.451060, 22.881819)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ ΛΙΒΑΔΕΙΑΣ-ΛΑΜΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 62345.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 4 χλμ Λιβαδειάς-Δελφών, ΔΗΜΟΣ ΛΕΒΑΔΕΩΝ, ΒΟΙΩΤΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2847.9m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 2847.9m)
#
# ID Stathmou: 49
# Pragmatikes syntetetagmenes: (38.451060, 22.881819)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ ΛΙΒΑΔΕΙΑΣ-ΛΑΜΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 62345.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ ΛΙΒΑΔΕΙΑΣ-ΛΑΜΙΑΣ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 63262.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ ΛΙΒΑΔΕΙΑΣ-ΛΑΜΙΑΣ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 63262.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ ΛΙΒΑΔΕΙΑΣ-ΛΑΜΙΑΣ, ΔΗΜΟΣ ΛΕΒΑΔΕΩΝ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1482.9m
#   → KALYTERI: run3 (APPROXIMATE, 1482.9m)
#
# ID Stathmou: 50
# Pragmatikes syntetetagmenes: (38.458562, 22.897496)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 3ο χλμ ΕΟ Λιβαδειάς-Λαμίας...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 61901.5m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ ΛΙΒΑΔΕΙΑΣ-ΛΑΜΙΑΣ, ΔΗΜΟΣ ΛΕΒΑΔΕΩΝ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1482.9m
#   → KALYTERI: run3 (APPROXIMATE, 1482.9m)
#
# ID Stathmou: 50
# Pragmatikes syntetetagmenes: (38.458562, 22.897496)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 3ο χλμ ΕΟ Λιβαδειάς-Λαμίας...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 61901.5m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 3ο χλμ ΕΟ Λιβαδειάς-Λαμίας, ΒΟΙΩΤΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 9218.9m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 3ο χλμ ΕΟ Λιβαδειάς-Λαμίας, ΒΟΙΩΤΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 9218.9m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 3ο χλμ ΕΟ Λιβαδειάς-Λαμίας, ΔΗΜΟΣ ΛΕΒΑΔΕΩΝ, ΒΟΙΩΤΙ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 9218.9m
#   → KALYTERI: run2 (GEOMETRIC_CENTER, 9218.9m)
#
# ID Stathmou: 57
# Pragmatikes syntetetagmenes: (38.348431, 23.172188)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 14ο ΧΛΜ ΘΗΒΩΝ -ΛΕΒΑΔΕΙΑΣ -ΒΟΙΩΤΙΑ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 6741.9m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 3ο χλμ ΕΟ Λιβαδειάς-Λαμίας, ΔΗΜΟΣ ΛΕΒΑΔΕΩΝ, ΒΟΙΩΤΙ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 9218.9m
#   → KALYTERI: run2 (GEOMETRIC_CENTER, 9218.9m)
#
# ID Stathmou: 57
# Pragmatikes syntetetagmenes: (38.348431, 23.172188)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 14ο ΧΛΜ ΘΗΒΩΝ -ΛΕΒΑΔΕΙΑΣ -ΒΟΙΩΤΙΑ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 6741.9m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 14ο ΧΛΜ ΘΗΒΩΝ -ΛΕΒΑΔΕΙΑΣ -ΒΟΙΩΤΙΑ, ΒΟΙΩΤΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 6741.9m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 14ο ΧΛΜ ΘΗΒΩΝ -ΛΕΒΑΔΕΙΑΣ -ΒΟΙΩΤΙΑ, ΒΟΙΩΤΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 6741.9m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 14ο ΧΛΜ ΘΗΒΩΝ -ΛΕΒΑΔΕΙΑΣ -ΒΟΙΩΤΙΑ, ΔΗΜΟΣ ΒΑΓΙΩΝ, Β...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 4017.7m
#   → KALYTERI: run3 (GEOMETRIC_CENTER, 4017.7m)
#
# ID Stathmou: 65
# Pragmatikes syntetetagmenes: (38.492281, 23.164325)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 110o ΧΛΜ ΑΘΗΝΩΝ-ΘΕΣΣΑΛΟΝΙΚΗΣ, ΚΑΣΤΡΟ...
#     → APPROXIMATE (vathmologia:1), apostasi: 74941.9m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 14ο ΧΛΜ ΘΗΒΩΝ -ΛΕΒΑΔΕΙΑΣ -ΒΟΙΩΤΙΑ, ΔΗΜΟΣ ΒΑΓΙΩΝ, Β...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 4017.7m
#   → KALYTERI: run3 (GEOMETRIC_CENTER, 4017.7m)
#
# ID Stathmou: 65
# Pragmatikes syntetetagmenes: (38.492281, 23.164325)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 110o ΧΛΜ ΑΘΗΝΩΝ-ΘΕΣΣΑΛΟΝΙΚΗΣ, ΚΑΣΤΡΟ...
#     → APPROXIMATE (vathmologia:1), apostasi: 74941.9m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 110o ΧΛΜ ΑΘΗΝΩΝ-ΘΕΣΣΑΛΟΝΙΚΗΣ, ΚΑΣΤΡΟ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 386.9m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 110o ΧΛΜ ΑΘΗΝΩΝ-ΘΕΣΣΑΛΟΝΙΚΗΣ, ΚΑΣΤΡΟ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 386.9m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 110o ΧΛΜ ΑΘΗΝΩΝ-ΘΕΣΣΑΛΟΝΙΚΗΣ, ΚΑΣΤΡΟ, ΔΗΜΟΣ ΘΗΒΑΙΩ...
#     → APPROXIMATE (vathmologia:1), apostasi: 74941.9m
#   → KALYTERI: run2 (APPROXIMATE, 386.9m)
#
# ID Stathmou: 66
# Pragmatikes syntetetagmenes: (38.306294, 23.319341)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ  Π.Ε.Ο. ΘΗΒΩΝ - ΑΘΗΝΩΝ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 45723.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 110o ΧΛΜ ΑΘΗΝΩΝ-ΘΕΣΣΑΛΟΝΙΚΗΣ, ΚΑΣΤΡΟ, ΔΗΜΟΣ ΘΗΒΑΙΩ...
#     → APPROXIMATE (vathmologia:1), apostasi: 74941.9m
#   → KALYTERI: run2 (APPROXIMATE, 386.9m)
#
# ID Stathmou: 66
# Pragmatikes syntetetagmenes: (38.306294, 23.319341)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ  Π.Ε.Ο. ΘΗΒΩΝ - ΑΘΗΝΩΝ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 45723.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ  Π.Ε.Ο. ΘΗΒΩΝ - ΑΘΗΝΩΝ, ΒΟΙΩΤΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 45723.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ  Π.Ε.Ο. ΘΗΒΩΝ - ΑΘΗΝΩΝ, ΒΟΙΩΤΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 45723.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ  Π.Ε.Ο. ΘΗΒΩΝ - ΑΘΗΝΩΝ, ΔΗΜΟΣ ΘΗΒΑΙΩΝ, ΒΟΙΩ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 45723.7m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 45723.7m)
#
# ID Stathmou: 68
# Pragmatikes syntetetagmenes: (38.375380, 23.268796)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 90 ΧΛΜ Ε.Ο ΑΘΗΝΩΝ-ΛΑΜΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 93059.3m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 1ο ΧΛΜ  Π.Ε.Ο. ΘΗΒΩΝ - ΑΘΗΝΩΝ, ΔΗΜΟΣ ΘΗΒΑΙΩΝ, ΒΟΙΩ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 45723.7m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 45723.7m)
#
# ID Stathmou: 68
# Pragmatikes syntetetagmenes: (38.375380, 23.268796)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 90 ΧΛΜ Ε.Ο ΑΘΗΝΩΝ-ΛΑΜΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 93059.3m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 90 ΧΛΜ Ε.Ο ΑΘΗΝΩΝ-ΛΑΜΙΑΣ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 93059.3m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 90 ΧΛΜ Ε.Ο ΑΘΗΝΩΝ-ΛΑΜΙΑΣ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 93059.3m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 90 ΧΛΜ Ε.Ο ΑΘΗΝΩΝ-ΛΑΜΙΑΣ, ΔΗΜΟΣ ΘΗΒΑΙΩΝ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 23309.4m
#   → KALYTERI: run3 (APPROXIMATE, 23309.4m)
#
# ID Stathmou: 14206
# Pragmatikes syntetetagmenes: (38.313826, 23.635998)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 56 ΧΛΜ Π.Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 123116.8m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 90 ΧΛΜ Ε.Ο ΑΘΗΝΩΝ-ΛΑΜΙΑΣ, ΔΗΜΟΣ ΘΗΒΑΙΩΝ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 23309.4m
#   → KALYTERI: run3 (APPROXIMATE, 23309.4m)
#
# ID Stathmou: 14206
# Pragmatikes syntetetagmenes: (38.313826, 23.635998)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 56 ΧΛΜ Π.Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 123116.8m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 56 ΧΛΜ Π.Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 123116.8m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 56 ΧΛΜ Π.Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ, ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 123116.8m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 56 ΧΛΜ Π.Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ, ΔΗΜΟΣ ΟΙΝΟΦΥΤΩΝ, ΒΟΙΩ...
#     → APPROXIMATE (vathmologia:1), apostasi: 696.0m
#   → KALYTERI: run3 (APPROXIMATE, 696.0m)
#
# ID Stathmou: 73
# Pragmatikes syntetetagmenes: (38.495358, 23.001290)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 2 ΧΛΜ ΟΡΧΟΜΕΝΟΥ-ΚΑΣΤΡΟΥ, ΟΡΧΟΜΕΝΟΣ ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1804.0m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 56 ΧΛΜ Π.Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ, ΔΗΜΟΣ ΟΙΝΟΦΥΤΩΝ, ΒΟΙΩ...
#     → APPROXIMATE (vathmologia:1), apostasi: 696.0m
#   → KALYTERI: run3 (APPROXIMATE, 696.0m)
#
# ID Stathmou: 73
# Pragmatikes syntetetagmenes: (38.495358, 23.001290)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 2 ΧΛΜ ΟΡΧΟΜΕΝΟΥ-ΚΑΣΤΡΟΥ, ΟΡΧΟΜΕΝΟΣ ΒΟΙΩΤΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1804.0m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 2 ΧΛΜ ΟΡΧΟΜΕΝΟΥ-ΚΑΣΤΡΟΥ, ΟΡΧΟΜΕΝΟΣ ΒΟΙΩΤΙΑΣ, ΒΟΙΩΤ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1804.8m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 2 ΧΛΜ ΟΡΧΟΜΕΝΟΥ-ΚΑΣΤΡΟΥ, ΟΡΧΟΜΕΝΟΣ ΒΟΙΩΤΙΑΣ, ΒΟΙΩΤ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1804.8m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 2 ΧΛΜ ΟΡΧΟΜΕΝΟΥ-ΚΑΣΤΡΟΥ, ΟΡΧΟΜΕΝΟΣ ΒΟΙΩΤΙΑΣ, ΔΗΜΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1804.8m
#   → KALYTERI: run1 (APPROXIMATE, 1804.0m)
#
# ID Stathmou: 80
# Pragmatikes syntetetagmenes: (38.331114, 23.602124)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 58+600 ΧΛΜ Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ ,ΔΙΟΔΙΑ ΣΧΗΜΑΤΑΡΙΟΥ...
#     → APPROXIMATE (vathmologia:1), apostasi: 119591.8m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 2 ΧΛΜ ΟΡΧΟΜΕΝΟΥ-ΚΑΣΤΡΟΥ, ΟΡΧΟΜΕΝΟΣ ΒΟΙΩΤΙΑΣ, ΔΗΜΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1804.8m
#   → KALYTERI: run1 (APPROXIMATE, 1804.0m)
#
# ID Stathmou: 80
# Pragmatikes syntetetagmenes: (38.331114, 23.602124)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 58+600 ΧΛΜ Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ ,ΔΙΟΔΙΑ ΣΧΗΜΑΤΑΡΙΟΥ...
#     → APPROXIMATE (vathmologia:1), apostasi: 119591.8m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 58+600 ΧΛΜ Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ ,ΔΙΟΔΙΑ ΣΧΗΜΑΤΑΡΙΟΥ,...
#     → APPROXIMATE (vathmologia:1), apostasi: 119591.8m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 58+600 ΧΛΜ Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ ,ΔΙΟΔΙΑ ΣΧΗΜΑΤΑΡΙΟΥ,...
#     → APPROXIMATE (vathmologia:1), apostasi: 119591.8m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 58+600 ΧΛΜ Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ ,ΔΙΟΔΙΑ ΣΧΗΜΑΤΑΡΙΟΥ,...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 463.4m
#   → KALYTERI: run3 (GEOMETRIC_CENTER, 463.4m)
#
# ID Stathmou: 95
# Pragmatikes syntetetagmenes: (38.388902, 23.592925)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5ο χλμ. ΧΑΛΚΙΔΟΣ-ΣΧΗΜΑΤΑΡΙΟΥ, ΑΥΛΙΔΑ, ΧΑΛΚΙΔΑ  222...
#     → APPROXIMATE (vathmologia:1), apostasi: 4838.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 58+600 ΧΛΜ Ε.Ο. ΑΘΗΝΩΝ-ΛΑΜΙΑΣ ,ΔΙΟΔΙΑ ΣΧΗΜΑΤΑΡΙΟΥ,...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 463.4m
#   → KALYTERI: run3 (GEOMETRIC_CENTER, 463.4m)
#
# ID Stathmou: 95
# Pragmatikes syntetetagmenes: (38.388902, 23.592925)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5ο χλμ. ΧΑΛΚΙΔΟΣ-ΣΧΗΜΑΤΑΡΙΟΥ, ΑΥΛΙΔΑ, ΧΑΛΚΙΔΑ  222...
#     → APPROXIMATE (vathmologia:1), apostasi: 4838.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5ο χλμ. ΧΑΛΚΙΔΟΣ-ΣΧΗΜΑΤΑΡΙΟΥ, ΑΥΛΙΔΑ, ΧΑΛΚΙΔΑ  222...
#     → APPROXIMATE (vathmologia:1), apostasi: 4838.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5ο χλμ. ΧΑΛΚΙΔΟΣ-ΣΧΗΜΑΤΑΡΙΟΥ, ΑΥΛΙΔΑ, ΧΑΛΚΙΔΑ  222...
#     → APPROXIMATE (vathmologia:1), apostasi: 4838.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5ο χλμ. ΧΑΛΚΙΔΟΣ-ΣΧΗΜΑΤΑΡΙΟΥ, ΑΥΛΙΔΑ, ΧΑΛΚΙΔΑ  222...
#     → APPROXIMATE (vathmologia:1), apostasi: 4838.6m
#   → KALYTERI: run1 (APPROXIMATE, 4838.6m)
#
# ID Stathmou: 11771
# Pragmatikes syntetetagmenes: (38.430993, 23.656475)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 8ο ΧΛΜ ΧΑΛΚΙΔΑΣ-ΒΑΣΙΛΙΚΟΥ...
#     → APPROXIMATE (vathmologia:1), apostasi: 5112.2m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5ο χλμ. ΧΑΛΚΙΔΟΣ-ΣΧΗΜΑΤΑΡΙΟΥ, ΑΥΛΙΔΑ, ΧΑΛΚΙΔΑ  222...
#     → APPROXIMATE (vathmologia:1), apostasi: 4838.6m
#   → KALYTERI: run1 (APPROXIMATE, 4838.6m)
#
# ID Stathmou: 11771
# Pragmatikes syntetetagmenes: (38.430993, 23.656475)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 8ο ΧΛΜ ΧΑΛΚΙΔΑΣ-ΒΑΣΙΛΙΚΟΥ...
#     → APPROXIMATE (vathmologia:1), apostasi: 5112.2m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 8ο ΧΛΜ ΧΑΛΚΙΔΑΣ-ΒΑΣΙΛΙΚΟΥ, ΕΥΒΟΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1506.8m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 8ο ΧΛΜ ΧΑΛΚΙΔΑΣ-ΒΑΣΙΛΙΚΟΥ, ΕΥΒΟΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1506.8m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 8ο ΧΛΜ ΧΑΛΚΙΔΑΣ-ΒΑΣΙΛΙΚΟΥ, ΔΗΜΟΣ ΛΗΛΑΝΤΙΩΝ, ΕΥΒΟΙΑ...
#     → APPROXIMATE (vathmologia:1), apostasi: 5112.2m
#   → KALYTERI: run2 (APPROXIMATE, 1506.8m)
#
# ID Stathmou: 13856
# Pragmatikes syntetetagmenes: (38.923757, 22.434768)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 3ο χλμ ΛΑΜΙΑΣ-ΔΟΜΟΚΟΥ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 4153.4m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 8ο ΧΛΜ ΧΑΛΚΙΔΑΣ-ΒΑΣΙΛΙΚΟΥ, ΔΗΜΟΣ ΛΗΛΑΝΤΙΩΝ, ΕΥΒΟΙΑ...
#     → APPROXIMATE (vathmologia:1), apostasi: 5112.2m
#   → KALYTERI: run2 (APPROXIMATE, 1506.8m)
#
# ID Stathmou: 13856
# Pragmatikes syntetetagmenes: (38.923757, 22.434768)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 3ο χλμ ΛΑΜΙΑΣ-ΔΟΜΟΚΟΥ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 4153.4m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 3ο χλμ 
�ΔΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 11965.8m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 208 ΧΛΜ ΑΘΗΝΩΝ-ΛΑΜΙΑΣ ΑΛΑΜΑΝΑ, ΛΑΜΙΑ, ΔΗΜΟΣ ΛΑΜΙΕΩ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3348.2m
#   → KALYTERI: run3 (GEOMETRIC_CENTER, 3348.2m)
#
# ID Stathmou: 131
# Pragmatikes syntetetagmenes: (38.780602, 22.713265)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: Παράπλευρη Οδός Ν.Ε.Ο. Αθηνών - Λαμίας  (180ο χλμ)...
#     → ROOFTOP (vathmologia:5), apostasi: 26324.1m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 208 ΧΛΜ ΑΘΗΝΩΝ-ΛΑΜΙΑΣ ΑΛΑΜΑΝΑ, ΛΑΜΙΑ, ΔΗΜΟΣ ΛΑΜΙΕΩ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3348.2m
#   → KALYTERI: run3 (GEOMETRIC_CENTER, 3348.2m)
#
# ID Stathmou: 131
# Pragmatikes syntetetagmenes: (38.780602, 22.713265)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: Παράπλευρη Οδός Ν.Ε.Ο. Αθηνών - Λαμίας  (180ο χλμ)...
#     → ROOFTOP (vathmologia:5), apostasi: 26324.1m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: Παράπλευρη Οδός Ν.Ε.Ο. Αθηνών - Λαμίας  (180ο χλμ)...
#     → APPROXIMATE (vathmologia:1), apostasi: 5924.8m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: Παράπλευρη Οδός Ν.Ε.Ο. Αθηνών - Λαμίας  (180ο χλμ)...
#     → APPROXIMATE (vathmologia:1), apostasi: 5924.8m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: Παράπλευρη Οδός Ν.Ε.Ο. Αθηνών - Λαμίας  (180ο χλμ)...
#     → APPROXIMATE (vathmologia:1), apostasi: 5924.8m
#   → KALYTERI: run2 (APPROXIMATE, 5924.8m)
#
# ID Stathmou: 13444
# Pragmatikes syntetetagmenes: (38.925972, 22.269112)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 16ΧΙΛ ΛΑΜΙΑΣ-ΚΑΡΠΕΝΗΣΙΟΥ...
#     → APPROXIMATE (vathmologia:1), apostasi: 41156.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: Παράπλευρη Οδός Ν.Ε.Ο. Αθηνών - Λαμίας  (180ο χλμ)...
#     → APPROXIMATE (vathmologia:1), apostasi: 5924.8m
#   → KALYTERI: run2 (APPROXIMATE, 5924.8m)
#
# ID Stathmou: 13444
# Pragmatikes syntetetagmenes: (38.925972, 22.269112)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 16ΧΙΛ ΛΑΜΙΑΣ-ΚΑΡΠΕΝΗΣΙΟΥ...
#     → APPROXIMATE (vathmologia:1), apostasi: 41156.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 16ΧΙΛ ΛΑΜΙΑΣ-ΚΑΡΠΕΝΗΣΙΟΥ, ΦΘΙΩΤΙΔΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 14539.2m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 16ΧΙΛ ΛΑΜΙΑΣ-ΚΑΡΠΕΝΗΣΙΟΥ, ΦΘΙΩΤΙΔΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 14539.2m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 16ΧΙΛ ΛΑΜΙΑΣ-ΚΑΡΠΕΝΗΣΙΟΥ, ΔΗΜΟΣ ΛΕΙΑΝΟΚΛΑΔΙΟΥ, ΦΘΙ...
#     → APPROXIMATE (vathmologia:1), apostasi: 3096.0m
#   → KALYTERI: run3 (APPROXIMATE, 3096.0m)
#
# ID Stathmou: 139
# Pragmatikes syntetetagmenes: (38.922089, 22.849578)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 250 ΧΛΜ.ΕΟ ΑΘΗΝΩΝ-ΘΕΣ/ΝΙΚΗΣ, ΔΙΟΔΙΑ ΠΕΛΑΣΓΙΑ...
#     → APPROXIMATE (vathmologia:1), apostasi: 129343.0m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for:

#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 11χιλ Ν.Ε.Ο ΛΑΜΙΑΣ-ΛΑΡΙΣΑΣ -ΦΘΙΩΤΙΔΑ, ΦΘΙΩΤΙΔΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 82785.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 11χιλ Ν.Ε.Ο ΛΑΜΙΑΣ-ΛΑΡΙΣΑΣ -ΦΘΙΩΤΙΔΑ, ΦΘΙΩΤΙΔΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 82785.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 11χιλ Ν.Ε.Ο ΛΑΜΙΑΣ-ΛΑΡΙΣΑΣ -ΦΘΙΩΤΙΔΑ, ΔΗΜΟΣ ΣΤΥΛΙΔ...
#     → APPROXIMATE (vathmologia:1), apostasi: 82785.6m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 12373.8m)
#
# ID Stathmou: 160
# Pragmatikes syntetetagmenes: (37.686551, 22.661400)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 10ο ΧΛΜ. ΑΡΓΟΥΣ -ΣΤΕΡΝΑΣ, ΑΡΓΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 8240.1m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 11χιλ Ν.Ε.Ο ΛΑΜΙΑΣ-ΛΑΡΙΣΑΣ -ΦΘΙΩΤΙΔΑ, ΔΗΜΟΣ ΣΤΥΛΙΔ...
#     → APPROXIMATE (vathmologia:1), apostasi: 82785.6m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 12373.8m)
#
# ID Stathmou: 160
# Pragmatikes syntetetagmenes: (37.686551, 22.661400)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 10ο ΧΛΜ. ΑΡΓΟΥΣ -ΣΤΕΡΝΑΣ, ΑΡΓΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 8240.1m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 10ο ΧΛΜ. ΑΡΓΟΥΣ -ΣΤΕΡΝΑΣ, ΑΡΓΟΣ, ΑΡΓΟΛΙΔΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 8240.1m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 10ο ΧΛΜ. ΑΡΓΟΥΣ -ΣΤΕΡΝΑΣ, ΑΡΓΟΣ, ΑΡΓΟΛΙΔΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 8240.1m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 10ο ΧΛΜ. ΑΡΓΟΥΣ -ΣΤΕΡΝΑΣ, ΑΡΓΟΣ, ΔΗΜΟΣ ΑΡΓΟΥΣ, ΑΡΓ...
#     → APPROXIMATE (vathmologia:1), apostasi: 8240.1m
#   → KALYTERI: run1 (APPROXIMATE, 8240.1m)
#
# ID Stathmou: 11799
# Pragmatikes syntetetagmenes: (37.657215, 22.726744)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 3 ΧΛΜ ΑΡΓΟΥΣ ΚΟΡΙΝΘΟΥ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 35476.0m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 10ο ΧΛΜ. ΑΡΓΟΥΣ -ΣΤΕΡΝΑΣ, ΑΡΓΟΣ, ΔΗΜΟΣ ΑΡΓΟΥΣ, ΑΡΓ...
#     → APPROXIMATE (vathmologia:1), apostasi: 8240.1m
#   → KALYTERI: run1 (APPROXIMATE, 8240.1m)
#
# ID Stathmou: 11799
# Pragmatikes syntetetagmenes: (37.657215, 22.726744)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 3 ΧΛΜ ΑΡΓΟΥΣ ΚΟΡΙΝΘΟΥ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 35476.0m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 3 ΧΛΜ ΑΡΓΟΥΣ ΚΟΡΙΝΘΟΥ, ΑΡΓΟΛΙΔΟΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1855.0m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 3 ΧΛΜ ΑΡΓΟΥΣ ΚΟΡΙΝΘΟΥ, ΑΡΓΟΛΙΔΟΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1855.0m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 3 ΧΛΜ ΑΡΓΟΥΣ ΚΟΡΙΝΘΟΥ, ΔΗΜΟΣ ΑΡΓΟΥΣ, ΑΡΓΟΛΙΔΟΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1855.0m
#   → KALYTERI: run2 (GEOMETRIC_CENTER, 1855.0m)
#
# ID Stathmou: 170
# Pragmatikes syntetetagmenes: (37.628380, 22.646081)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 9οΧΛΜ ΑΡΓΟΥΣ-ΚΑΡΥΑΣ,ΧΟΥΝΗ...
#     → APPROXIMATE (vathmologia:1), apostasi: 824.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 3 ΧΛΜ ΑΡΓΟΥΣ ΚΟΡΙΝΘΟΥ, ΔΗΜΟΣ ΑΡΓΟΥΣ, ΑΡΓΟΛΙΔΟΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1855.0m
#   → KALYTERI: run2 (GEOMETRIC_CENTER, 1855.0m)
#
# ID Stathmou: 170
# Pragmatikes syntetetagmenes: (37.628380, 22.646081)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 9οΧΛΜ ΑΡΓΟΥΣ-ΚΑΡΥΑΣ,ΧΟΥΝΗ...
#     → APPROXIMATE (vathmologia:1), apostasi: 824.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 9οΧΛΜ ΑΡΓΟΥΣ-ΚΑΡΥΑΣ,ΧΟΥΝΗ, ΑΡΓΟΛΙΔΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 824.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 9οΧΛΜ ΑΡΓΟΥΣ-ΚΑΡΥΑΣ,ΧΟΥΝΗ, ΑΡΓΟΛΙΔΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 824.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 9οΧΛΜ ΑΡΓΟΥΣ-ΚΑΡΥΑΣ,ΧΟΥΝΗ, ΔΗΜΟΣ ΛΥΡΚΕΙΑΣ, ΑΡΓΟΛΙΔ...
#     → APPROXIMATE (vathmologia:1), apostasi: 11886.1m
#   → KALYTERI: run1 (APPROXIMATE, 824.7m)
#
# ID Stathmou: 175
# Pragmatikes syntetetagmenes: (37.476705, 22.400382)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ Ε.Ο. ΤΡΙΠΟΛΗΣ - ΣΠΑΡΤΗΣ - ΤΡΙΠΟΛΗ ΑΡΚΑΔΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3584.4m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ Ε.Ο. ΤΡΙΠΟΛΗΣ - ΣΠΑΡΤΗΣ - ΤΡΙΠΟΛΗ ΑΡΚΑΔΙΑΣ,...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3584.4m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 9οΧΛΜ ΑΡΓΟΥΣ-ΚΑΡΥΑΣ,ΧΟΥΝΗ, ΔΗΜΟΣ ΛΥΡΚΕΙΑΣ, ΑΡΓΟΛΙΔ...
#     → APPROXIMATE (vathmologia:1), apostasi: 11886.1m
#   → KALYTERI: run1 (APPROXIMATE, 824.7m)
#
# ID Stathmou: 175
# Pragmatikes syntetetagmenes: (37.476705, 22.400382)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ Ε.Ο. ΤΡΙΠΟΛΗΣ - ΣΠΑΡΤΗΣ - ΤΡΙΠΟΛΗ ΑΡΚΑΔΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3584.4m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ Ε.Ο. ΤΡΙΠΟΛΗΣ - ΣΠΑΡΤΗΣ - ΤΡΙΠΟΛΗ ΑΡΚΑΔΙΑΣ,...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3584.4m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ Ε.Ο. ΤΡΙΠΟΛΗΣ - ΣΠΑΡΤΗΣ - ΤΡΙΠΟΛΗ ΑΡΚΑΔΙΑΣ,...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3584.4m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 3584.4m)
#
# ID Stathmou: 179
# Pragmatikes syntetetagmenes: (37.496301, 22.435960)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5ΧΛΜ Π.Ε.Ο.ΤΡΙΠΟΛΗΣ ΑΡΓΟΥΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 5793.3m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5ΧΛΜ Π.Ε.Ο.ΤΡΙΠΟΛΗΣ ΑΡΓΟΥΣ, ΑΡΚΑΔΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 30081.5m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5ο ΧΛΜ Ε.Ο. ΤΡΙΠΟΛΗΣ - ΣΠΑΡΤΗΣ - ΤΡΙΠΟΛΗ ΑΡΚΑΔΙΑΣ,...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3584.4m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 3584.4m)
#
# ID Stathmou: 179
# Pragmatikes syntetetagmenes: (37.496301, 22.435960)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5ΧΛΜ Π.Ε.Ο.ΤΡΙΠΟΛΗΣ ΑΡΓΟΥΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 5793.3m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5ΧΛΜ Π.Ε.Ο.ΤΡΙΠΟΛΗΣ ΑΡΓΟΥΣ, ΑΡΚΑΔΙΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 30081.5m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5ΧΛΜ Π.Ε.Ο.ΤΡΙΠΟΛΗΣ ΑΡΓΟΥΣ, ΔΗΜΟΣ ΚΟΡΥΘΙΟΥ, ΑΡΚΑΔΙ...
#     → APPROXIMATE (vathmologia:1), apostasi: 4861.6m
#   → KALYTERI: run3 (APPROXIMATE, 4861.6m)
#
# ID Stathmou: 223
# Pragmatikes syntetetagmenes: (38.235208, 22.078664)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: ΝΕΟ ΑΘΗΝΩΝ ΠΑΤΡΩΝ 175 ΧΛΜ ΑΡΙΣΤΕΡΑ...
#     → ROOFTOP (vathmologia:5), apostasi: 67471.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: ΝΕΟ ΑΘΗΝΩΝ ΠΑΤΡΩΝ 175 ΧΛΜ ΑΡΙΣΤΕΡΑ, ΑΧΑΪΑΣ...
#     → RANGE_INTERPOLATED (vathmologia:3), apostasi: 4231.4m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5ΧΛΜ Π.Ε.Ο.ΤΡΙΠΟΛΗΣ ΑΡΓΟΥΣ, ΔΗΜΟΣ ΚΟΡΥΘΙΟΥ, ΑΡΚΑΔΙ...
#     → APPROXIMATE (vathmologia:1), apostasi: 4861.6m
#   → KALYTERI: run3 (APPROXIMATE, 4861.6m)
#
# ID Stathmou: 223
# Pragmatikes syntetetagmenes: (38.235208, 22.078664)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: ΝΕΟ ΑΘΗΝΩΝ ΠΑΤΡΩΝ 175 ΧΛΜ ΑΡΙΣΤΕΡΑ...
#     → ROOFTOP (vathmologia:5), apostasi: 67471.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: ΝΕΟ ΑΘΗΝΩΝ ΠΑΤΡΩΝ 175 ΧΛΜ ΑΡΙΣΤΕΡΑ, ΑΧΑΪΑΣ...
#     → RANGE_INTERPOLATED (vathmologia:3), apostasi: 4231.4m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: ΝΕΟ ΑΘΗΝΩΝ ΠΑΤΡΩΝ 175 ΧΛΜ ΑΡΙΣΤΕΡΑ, ΔΗΜΟΣ ΑΙΓΙΟΥ, ...
#     → RANGE_INTERPOLATED (vathmologia:3), apostasi: 4231.4m
#   → KALYTERI: run2 (RANGE_INTERPOLATED, 4231.4m)
#
# ID Stathmou: 224
# Pragmatikes syntetetagmenes: (38.235404, 22.079850)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 175 ΧΙΛ ΝΕΟ ΑΘΗΝΑ ΠΑΤΡΑ...
#     → APPROXIMATE (vathmologia:1), apostasi: 146846.4m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 175 ΧΙΛ ΝΕΟ ΑΘΗΝΑ ΠΑΤΡΑ, ΑΧΑΪΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 29265.4m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: ΝΕΟ ΑΘΗΝΩΝ ΠΑΤΡΩΝ 175 ΧΛΜ ΑΡΙΣΤΕΡΑ, ΔΗΜΟΣ ΑΙΓΙΟΥ, ...
#     → RANGE_INTERPOLATED (vathmologia:3), apostasi: 4231.4m
#   → KALYTERI: run2 (RANGE_INTERPOLATED, 4231.4m)
#
# ID Stathmou: 224
# Pragmatikes syntetetagmenes: (38.235404, 22.079850)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for:
�ΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1529.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 9 ΧΙΛ ΠΕΟ ΡΟΙΤΙΚΑ ΠΑΤΡΩΝ, ΔΗΜΟΣ ΠΑΡΑΛΙΑΣ, ΑΧΑΪΑΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 597.4m
#   → KALYTERI: run2 (APPROXIMATE, 597.4m)
#
# ID Stathmou: 240
# Pragmatikes syntetetagmenes: (37.683648, 21.418388)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 2ο χλμ ΠΥΡΓΟΥ - ΠΑΤΡΩΝ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1529.6m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 2ο χλμ ΠΥΡΓΟΥ - ΠΑΤΡΩΝ, ΗΛΕΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1529.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 2ο χλμ ΠΥΡΓΟΥ - ΠΑΤΡΩΝ, ΔΗΜΟΣ ΠΥΡΓΟΥ, ΗΛΕΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1529.6m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 1529.6m)
#
# ID Stathmou: 244
# Pragmatikes syntetetagmenes: (37.681318, 21.419891)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 95 ΧΙΛ Ε.Ο ΠΑΤΡΩΝ-ΠΥΡΓΟΥ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1280.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 95 ΧΙΛ Ε.Ο ΠΑΤΡΩΝ-ΠΥΡΓΟΥ, ΗΛΕΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1280.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 2ο χλμ ΠΥΡΓΟΥ - ΠΑΤΡΩΝ, ΔΗΜΟΣ ΠΥΡΓΟΥ, ΗΛΕΙΑΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 1529.6m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 1529.6m)
#
# ID Stathmou: 244
# Pragmatikes syntetetagmenes: (37.681318, 21.419891)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 95 ΧΙΛ Ε.Ο ΠΑΤΡΩΝ-ΠΥΡΓΟΥ...
# ...
#     → RANGE_INTERPOLATED (vathmologia:3), apostasi: 1183.2m
#   → KALYTERI: run2 (RANGE_INTERPOLATED, 971.8m)
#
# ID Stathmou: 408
# Pragmatikes syntetetagmenes: (39.710769, 20.798306)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 7 ΧΛΜ.ΙΩΑΝΝΙΝΩΝ-ΚΟΝΙΤΣΗΣ, ΕΛΕΟΥΣΑ ΙΩΑΝΝΙΝΩΝ...
#     → APPROXIMATE (vathmologia:1), apostasi: 698.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 7 ΧΛΜ.ΙΩΑΝΝΙΝΩΝ-ΚΟΝΙΤΣΗΣ, ΕΛΕΟΥΣΑ ΙΩΑΝΝΙΝΩΝ, ΙΩΑΝΝ...
#     → APPROXIMATE (vathmologia:1), apostasi: 698.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: ΛΕΩΦ. ΣΤΑΥΡΟΥ ΝΙΑΡΧΟΥ (1o χλμ.Ε.Ο Ιωαννίνων-Δωδώνη...
#     → RANGE_INTERPOLATED (vathmologia:3), apostasi: 1183.2m
#   → KALYTERI: run2 (RANGE_INTERPOLATED, 971.8m)
#
# ID Stathmou: 408
# Pragmatikes syntetetagmenes: (39.710769, 20.798306)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 7 ΧΛΜ.ΙΩΑΝΝΙΝΩΝ-ΚΟΝΙΤΣΗΣ, ΕΛΕΟΥΣΑ ΙΩΑΝΝΙΝΩΝ...
#     → APPROXIMATE (vathmologia:1), apostasi: 698.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 7 ΧΛΜ.ΙΩΑΝΝΙΝΩΝ-ΚΟΝΙΤΣΗΣ, ΕΛΕΟΥΣΑ ΙΩΑΝΝΙΝΩΝ, ΙΩΑΝΝ...
#     → APPROXIMATE (vathmologia:1), apostasi: 698.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 7 ΧΛΜ.ΙΩΑΝΝΙΝΩΝ-ΚΟΝΙΤΣΗΣ, ΕΛΕΟΥΣΑ ΙΩΑΝΝΙΝΩΝ, ΔΗΜΟΣ...
#     → APPROXIMATE (vathmologia:1), apostasi:
7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 6ο ΧΛΜ.ΚΑΡΔΙΤΣΑΣ-ΚΑΛΛΙΘΗΡΟ, ΚΑΡΔΙΤΣΑ, ΔΗΜΟΣ ΚΑΡΔΙΤ...
#     → APPROXIMATE (vathmologia:1), apostasi: 4158.2m
#   → KALYTERI: run1 (APPROXIMATE, 4158.2m)
#
# ID Stathmou: 433
# Pragmatikes syntetetagmenes: (39.369964, 21.980874)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5 ΧΛΜ ΚΑΡΔΙΤΣΑΣ ΑΘΗΝΩΝ...
#     → APPROXIMATE (vathmologia:1), apostasi: 216201.4m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5 ΧΛΜ ΚΑΡΔΙΤΣΑΣ ΑΘΗΝΩΝ, ΚΑΡΔΙΤΣΗΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 5148.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5 ΧΛΜ ΚΑΡΔΙΤΣΑΣ ΑΘΗΝΩΝ, ΔΗΜΟΣ ΚΑΜΠΟΥ, ΚΑΡΔΙΤΣΗΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 216201.4m
#   → KALYTERI: run2 (GEOMETRIC_CENTER, 5148.7m)
#
# ID Stathmou: 14822
# Pragmatikes syntetetagmenes: (39.377557, 22.022724)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 10οΧΙΛ Καρδιτσας Λαρισας...
#     → APPROXIMATE (vathmologia:1), apostasi: 44741.2m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 10οΧΙΛ Καρδιτσας Λαρισας, ΚΑΡΔΙΤΣΗΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 42973.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5 ΧΛΜ ΚΑΡΔΙΤΣΑΣ ΑΘΗΝΩΝ, ΔΗΜΟΣ ΚΑΜΠΟΥ, ΚΑΡΔΙΤΣΗΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 216201.4m
#   → KALYTERI: run2 (GEOMETRIC_CENTER, 5148.7m)
#
# ID Stathmou: 14822
# Pragmatikes syntetetagmenes: (39.377557, 22.022724)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 10οΧΙΛ Καρδιτσας Λαρισας...
#     → APPROXIMATE (vathmologia:1), apostasi: 44741.2m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 10οΧΙΛ Καρδιτσας Λαρισας, ΚΑΡΔΙΤΣΗΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 42973.6m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 10οΧΙΛ Καρδιτσας Λαρισας, ΔΗΜΟΣ ΚΑΜΠΟΥ, ΚΑΡΔΙΤΣΗΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 42973.6m
#   → KALYTERI: run2 (GEOMETRIC_CENTER, 42973.6m)
#
# ID Stathmou: 442
# Pragmatikes syntetetagmenes: (39.626374, 22.473753)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5 ΧΛΜ. ΠΕΟ ΛΑΡΙΣΑΣ-ΒΟΛΟΥ, ΛΑΡΙΣΑ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2476.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5 ΧΛΜ. ΠΕΟ ΛΑΡΙΣΑΣ-ΒΟΛΟΥ, ΛΑΡΙΣΑ, ΛΑΡΙΣΗΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2476.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 10οΧΙΛ Καρδιτσας Λαρισας, ΔΗΜΟΣ ΚΑΜΠΟΥ, ΚΑΡΔΙΤΣΗΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 42973.6m
#   → KALYTERI: run2 (GEOMETRIC_CENTER, 42973.6m)
#
# ID Stathmou: 442
# Pragmatikes syntetetagmenes: (39.626374, 22.473753)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 5 ΧΛΜ. ΠΕΟ ΛΑΡΙΣΑΣ-ΒΟΛΟΥ, ΛΑΡΙΣΑ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2476.7m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 5 ΧΛΜ. ΠΕΟ ΛΑΡΙΣΑΣ-ΒΟΛΟΥ, ΛΑΡΙΣΑ, ΛΑΡΙΣΗΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2476.7m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5 ΧΛΜ. ΠΕΟ ΛΑΡΙΣΑΣ-ΒΟΛΟΥ, ΛΑΡΙΣΑ, ΔΗΜΟΣ ΛΑΡΙΣΑΣ, Λ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2476.7m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 2476.7m)
#
# ID Stathmou: 13672
# Pragmatikes syntetetagmenes: (39.660329, 22.440417)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 3o ΧΛΜ Ε.Ο ΛΑΡΙΣΑΣ-ΘΕΣΣΑΛΟΝΙΚΗΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2989.3m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 3o ΧΛΜ Ε.Ο ΛΑΡΙΣΑΣ-ΘΕΣΣΑΛΟΝΙΚΗΣ, ΛΑΡΙΣΗΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2989.3m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 5 ΧΛΜ. ΠΕΟ ΛΑΡΙΣΑΣ-ΒΟΛΟΥ, ΛΑΡΙΣΑ, ΔΗΜΟΣ ΛΑΡΙΣΑΣ, Λ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 2476.7m
#   → KALYTERI: run1 (GEOMETRIC_CENTER, 2476.7m)
#
# ID Stathmou: 13672
# Pragmatikes syntetetagmenes: (39.660329, 22.440417)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 3o ΧΛΜ Ε.Ο ΛΑΡΙΣΑΣ-ΘΕΣΣΑΛΟΝΙΚΗΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2989.3m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 3o ΧΛΜ Ε.Ο ΛΑΡΙΣΑΣ-ΘΕΣΣΑΛΟΝΙΚΗΣ, ΛΑΡΙΣΗΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2989.3m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 3o ΧΛΜ Ε.Ο ΛΑΡΙΣΑΣ-ΘΕΣΣΑΛΟΝΙΚΗΣ, ΔΗΜΟΣ ΛΑΡΙΣΑΣ, ΛΑ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2989.3m
#   → KALYTERI: run1 (APPROXIMATE, 2989.3m)
#
# ID Stathmou: 12777
# Pragmatikes syntetetagmenes: (39.658505, 22.405626)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 3ο ΧΛΜ ΛΑΡΙΣΑΣ ΤΥΡΝΑΒΟΥ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2455.4m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 3ο ΧΛΜ ΛΑΡΙΣΑΣ ΤΥΡΝΑΒΟΥ, ΛΑΡΙΣΗΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2455.4m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 3o ΧΛΜ Ε.Ο ΛΑΡΙΣΑΣ-ΘΕΣΣΑΛΟΝΙΚΗΣ, ΔΗΜΟΣ ΛΑΡΙΣΑΣ, ΛΑ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2989.3m
#   → KALYTERI: run1 (APPROXIMATE, 2989.3m)
#
# ID Stathmou: 12777
# Pragmatikes syntetetagmenes: (39.658505, 22.405626)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 3ο ΧΛΜ ΛΑΡΙΣΑΣ ΤΥΡΝΑΒΟΥ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2455.4m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 3ο ΧΛΜ ΛΑΡΙΣΑΣ ΤΥΡΝΑΒΟΥ, ΛΑΡΙΣΗΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 2455.4m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 3ο ΧΛΜ ΛΑΡΙΣΑΣ ΤΥΡΝΑΒΟΥ, ΔΗΜΟΣ ΓΙΑΝΝΟΥΛΗΣ, ΛΑΡΙΣΗΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1261.1m
#   → KALYTERI: run3 (APPROXIMATE, 1261.1m)
#
# ID Stathmou: 450
# Pragmatikes syntetetagmenes: (39.663919, 22.443589)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 4ο ΧΛΜ Ε.Ο ΛΑΡΙΣΗΣ - ΘΕΣ/ΚΗΣ, ΛΑΡΙΣΑ...
#     → APPROXIMATE (vathmologia:1), apostasi: 116589.5m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 4ο ΧΛΜ Ε.Ο ΛΑΡΙΣΗΣ - ΘΕΣ/ΚΗΣ, ΛΑΡΙΣΑ, ΛΑΡΙΣΗΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3072.4m
#   Run 3: diefthinsi + dimos + nomos
#     [CACHE HIT] Using cached result for: 3ο ΧΛΜ ΛΑΡΙΣΑΣ ΤΥΡΝΑΒΟΥ, ΔΗΜΟΣ ΓΙΑΝΝΟΥΛΗΣ, ΛΑΡΙΣΗΣ...
#     → APPROXIMATE (vathmologia:1), apostasi: 1261.1m
#   → KALYTERI: run3 (APPROXIMATE, 1261.1m)
#
# ID Stathmou: 450
# Pragmatikes syntetetagmenes: (39.663919, 22.443589)
#   Run 1: mono diefthinsi
#     [CACHE HIT] Using cached result for: 4ο ΧΛΜ Ε.Ο ΛΑΡΙΣΗΣ - ΘΕΣ/ΚΗΣ, ΛΑΡΙΣΑ...
#     → APPROXIMATE (vathmologia:1), apostasi: 116589.5m
#   Run 2: diefthinsi + nomos
#     [CACHE HIT] Using cached result for: 4ο ΧΛΜ Ε.Ο ΛΑΡΙΣΗΣ - ΘΕΣ/ΚΗΣ, ΛΑΡΙΣΑ, ΛΑΡΙΣΗΣ...
#     → GEOMETRIC_CENTER (vathmologia:2), apostasi: 3072.4m
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       8     print(f"\nID Stathmou: {row['gasStationID']}")
#       9     print(f"Pragmatikes syntetetagmenes: ({row['gasStationLat']:.6f}, {row['gasStationLong']:.6f})")
# ---> 11     results = compare_methods(row)
#      13     test_results.append({
#      14         'gasStationID': row['gasStationID'],
#      15         'ground_truth_lat': row['gasStationLat'],
#      16         'ground_truth_lng': row['gasStationLong'],
#      17         **results
#      18     })
#      20 print("\n")
#
# Cell In[3], line 135, in compare_methods(row)
#     132     results['run2'] = None
#     133     print(f"    → APOTYCHIA")
# --> 135 time.sleep(0.1)
#     137 # Run 3: Address + Municipality + County
#     138 query3 = f"{address}, {municipality}, {county}"
#
# KeyboardInterrupt:

# %% [markdown]
# ### 6. Εξαγωγή σε Excel

# %%
# Prepare data for Excel export - etoimasia dedomenon gia Excel
excel_data = []

for r in test_results:
    station_id = r['gasStationID']
    gt_lat = r['ground_truth_lat']
    gt_lng = r['ground_truth_lng']
    
    # Get original data for additional fields - pairno ta arxika dedomena
    original_row = df_sample[df_sample['gasStationID'] == station_id].iloc[0]
    
    row_data = {
        'gasStationID': station_id,
        'gasStationAddress': original_row['gasStationAddress'],
        'gasStationLat': gt_lat,
        'gasStationLong': gt_lng,
        'ddName': original_row.get('ddName', ''),
        'municipalityName': original_row.get('municipalityName', ''),
        'countyName': original_row.get('countyName', ''),
    }
    
    # Only keep the best result (kalytero run mono)
    if r.get('best'):
        row_data.update({
            'best_lat': r['best']['lat'],
            'best_lng': r['best']['lng'],
            'best_accuracy': r['best']['accuracy'],
            'best_distance': r['best']['distance'],
            'best_score': r['best']['score'],
            'best_run': r['best'].get('best_method', '')  # poio run itan kalytero
        })
    
    excel_data.append(row_data)

excel_df = pd.DataFrame(excel_data)

# Save to Excel - apothikefsi se Excel
excel_df.to_excel(OUTPUT_FILE, index=False)

print(f"\nTa apotelesmata apothikeytikan sto: {OUTPUT_FILE}")
print(f"Periechei {len(excel_df)} grammes me ta arxika dedomena kai mono to kalytero run gia kathe stathmo (OLES OI EGRAFES)")

# %% [markdown]
# ### 7. Τελική Σύσταση

# %%
print("\n")
print("TELIKI SYSTASI")
print("\n")

# Summary for full dataset - perilepsi gia olo to dataset
print(f"\nOloklirothike i sigkrisi gia {len(test_results)} stathmous (OLES OI EGRAFES)")
print("Ta apotelesmata apothikeytikan sto Excel arxeio")
print("\nTo Excel periechei:")
print("- Ta arxika dedomena kathe stathmou")
print("- Mono to kalytero run (me mikroteri apostasi)")
print("- Ti methodo chrisimopoithike (run1, run2, i run3)")
print("- Akriveia kai apostasi tou kalyterou run")
print(f"\nSynolikos xronos geocoding: {len(test_results) * 3} API calls")
print(f"Cache efficiency: Blepete ta Cache Statistics parakatw")
print("\n")
